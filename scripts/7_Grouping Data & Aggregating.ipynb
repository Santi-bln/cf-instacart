# %% [markdown]
# # 01. Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Importing data

# %%
path = r'C:\Users\santi\HiDrive\users\santina\02_Data Analytics\04_Python-Fundamentals\02-2022 Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\santi\\HiDrive\\users\\santina\\02_Data Analytics\\04_Python-Fundamentals\\02-2022 Instacart Basket Analysis'

# %%
# import the ords_prods_merged data frame
ords_prods_merge = pd.read_pickle(os.path.join(path, '02_Data', 'Prepared Data', 'orders_products_merged.pkl' ))

# %%
# subset first 1.000.000 rows
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 21)

# %%
df.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 0           0   2539329        1    prior             1          2
# 1           1   2539329        1    prior             1          2
# 2           2   2539329        1    prior             1          2
# 3           3   2539329        1    prior             1          2
# 4           4   2539329        1    prior             1          2
#
#    order_hour_of_day  days_since_prior_order  first_order  product_id  ...  \
# 0                  8                     NaN         True         196  ...
# 1                  8                     NaN         True       14084  ...
# 2                  8                     NaN         True       12427  ...
# 3                  8                     NaN         True       26088  ...
# 4                  8                     NaN         True       26405  ...
#
#    reordered                             product_name aisle_id  department_id  \
# ...

# %%
# group data by product_name
df.groupby('product_name')

# %%
# group by department_id
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1.0              14.792915
# 2.0              17.091743
# 3.0              17.919589
# 4.0              17.891973
# 5.0              15.214270
# 6.0              15.382228
# 7.0              17.699986
# 8.0              16.485269
# 9.0              15.965921
# 10.0             20.091818
# 11.0             16.485395
# 12.0             15.615845
# 13.0             16.485052
# 14.0             17.523474
# 15.0             15.690354
# 16.0             18.014342
# 17.0             16.155822
# 18.0             19.606536
# 19.0             17.630236
# 20.0             17.138204
# 21.0             21.996844

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1.0     14.792915
# 2.0     17.091743
# 3.0     17.919589
# 4.0     17.891973
# 5.0     15.214270
# 6.0     15.382228
# 7.0     17.699986
# 8.0     16.485269
# 9.0     15.965921
# 10.0    20.091818
# 11.0    16.485395
# 12.0    15.615845
# 13.0    16.485052
# 14.0    17.523474
# 15.0    15.690354
# 16.0    18.014342
# 17.0    16.155822
# 18.0    19.606536
# 19.0    17.630236
# 20.0    17.138204
# 21.0    21.996844
# Name: order_number, dtype: float64

# %%
# perform multiple aggregations
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1.0              14.792915   1  99
# 2.0              17.091743   1  98
# 3.0              17.919589   1  99
# 4.0              17.891973   1  99
# 5.0              15.214270   1  99
# 6.0              15.382228   1  99
# 7.0              17.699986   1  99
# 8.0              16.485269   1  91
# 9.0              15.965921   1  99
# 10.0             20.091818   1  99
# 11.0             16.485395   1  99
# 12.0             15.615845   1  99
# 13.0             16.485052   1  99
# 14.0             17.523474   1  99
# 15.0             15.690354   1  99
# 16.0             18.014342   1  99
# 17.0             16.155822   1  99
# 18.0             19.606536   1  99
# 19.0             17.630236   1  99
# 20.0             17.138204   1  99
# 21.0             21.996844   1  97

# %%
# create flags for loyalty in ords_prods_merge df
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 0            0   2539329        1    prior             1          2
# 1            1   2539329        1    prior             1          2
# 2            2   2539329        1    prior             1          2
# 3            3   2539329        1    prior             1          2
# 4            4   2539329        1    prior             1          2
# 5            5   2398795        1    prior             2          3
# 6            6   2398795        1    prior             2          3
# 7            7   2398795        1    prior             2          3
# 8            8   2398795        1    prior             2          3
# 9            9   2398795        1    prior             2          3
# 10          10   2398795        1    prior             2          3
# 11          11    473747        1    prior             3          3
# 12          12    473747        1    prior             3          3
# ...

# %%
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(15)
# Out:
#     Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 0            0   2539329        1    prior             1          2
# 1            1   2539329        1    prior             1          2
# 2            2   2539329        1    prior             1          2
# 3            3   2539329        1    prior             1          2
# 4            4   2539329        1    prior             1          2
# 5            5   2398795        1    prior             2          3
# 6            6   2398795        1    prior             2          3
# 7            7   2398795        1    prior             2          3
# 8            8   2398795        1    prior             2          3
# 9            9   2398795        1    prior             2          3
# 10          10   2398795        1    prior             2          3
# 11          11    473747        1    prior             3          3
# 12          12    473747        1    prior             3          3
# ...

# %%
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 0            0   2539329        1    prior             1          2
# 1            1   2539329        1    prior             1          2
# 2            2   2539329        1    prior             1          2
# 3            3   2539329        1    prior             1          2
# 4            4   2539329        1    prior             1          2
# 5            5   2398795        1    prior             2          3
# 6            6   2398795        1    prior             2          3
# 7            7   2398795        1    prior             2          3
# 8            8   2398795        1    prior             2          3
# 9            9   2398795        1    prior             2          3
# 10          10   2398795        1    prior             2          3
# 11          11    473747        1    prior             3          3
# 12          12    473747        1    prior             3          3
# ...

# %%
#add loyalty flag

ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15891507
# Loyal customer      10294027
# New customer         6249525
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merge.head(5)
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 0           0   2539329        1    prior             1          2
# 1           1   2539329        1    prior             1          2
# 2           2   2539329        1    prior             1          2
# 3           3   2539329        1    prior             1          2
# 4           4   2539329        1    prior             1          2
#
#    order_hour_of_day  days_since_prior_order  first_order  product_id  ...  \
# 0                  8                     NaN         True         196  ...
# 1                  8                     NaN         True       14084  ...
# 2                  8                     NaN         True       12427  ...
# 3                  8                     NaN         True       26088  ...
# 4                  8                     NaN         True       26405  ...
#
#    aisle_id  department_id prices  _merge    price_range_loc     busiest_day  \
# ...

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             1
# 2         1      New customer             1
# 3         1      New customer             1
# 4         1      New customer             1
# 5         1      New customer             2
# 6         1      New customer             2
# 7         1      New customer             2
# 8         1      New customer             2
# 9         1      New customer             2
# 10        1      New customer             2
# 11        1      New customer             3
# 12        1      New customer             3
# 13        1      New customer             3
# 14        1      New customer             3
# 15        1      New customer             3
# 16        1      New customer             4
# 17        1      New customer             4
# 18        1      New customer             4
# 19        1      New customer             4
# ...

# %%
# aggregated mean of the “order_number” column grouped by “department_id” for entire data frame.
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1.0              15.457838
# 2.0              17.277920
# 3.0              17.170395
# 4.0              17.811403
# 5.0              15.215751
# 6.0              16.439806
# 7.0              17.225802
# 8.0              15.340650
# 9.0              15.895474
# 10.0             20.197148
# 11.0             16.170638
# 12.0             15.887671
# 13.0             16.583536
# 14.0             16.773669
# 15.0             16.165037
# 16.0             17.665606
# 17.0             15.694469
# 18.0             19.310397
# 19.0             17.177343
# 20.0             16.473447
# 21.0             22.902379

# %%
# Analyze the result/ compare the subset to the entire data frame
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1.0              14.792915
# 2.0              17.091743
# 3.0              17.919589
# 4.0              17.891973
# 5.0              15.214270
# 6.0              15.382228
# 7.0              17.699986
# 8.0              16.485269
# 9.0              15.965921
# 10.0             20.091818
# 11.0             16.485395
# 12.0             15.615845
# 13.0             16.485052
# 14.0             17.523474
# 15.0             15.690354
# 16.0             18.014342
# 17.0             16.155822
# 18.0             19.606536
# 19.0             17.630236
# 20.0             17.138204
# 21.0             21.996844

# %% [markdown]
# The two sets are extremely close in their means with the first 1000000 having a slightly higher mean than the group as a whole. This can make sense as sections of the data can differ slightly from the whole, but it all gravitates toward the mean of the whole.

# %%
# check spending habits of the three types of customers identified
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# Loyal customers tend to spend an average of $10 while newer customers spend 13 and regular customers spend 12,5 It can be seen that in my dataframe there must still be a mistake in the higherst price of a product.

# %%
# Create spending flag for each user based on the average price across all their 
#If the mean of the prices of products purchased by a user is lower than 10,  flag as a “Low spender.”
#If the mean of the prices of products purchased by a user is higher than or equal to 10, flag as a “High spender.”

ords_prods_merge.groupby('user_id').agg({'prices': ['mean', 'min', 'max']}).head(5)
# Out:
#            prices
#              mean  min   max
# user_id
# 1        6.367797  1.0  14.0
# 2        7.515897  1.3  14.8
# 3        8.197727  1.3  14.4
# 4        8.205556  1.4  14.6
# 5        9.189189  3.2  14.8

# %%
ords_prods_merge['spending'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

ords_prods_merge.loc[ords_prods_merge['spending'] < 10, 'spending_flag'] = 'Low Spender'
ords_prods_merge.loc[ords_prods_merge['spending'] >= 10, 'spending_flag'] = 'High Spender'

# %%
df_1 = ords_prods_merge[['user_id', 'spending_flag', 'spending']]

# %%
ords_prods_merge[['user_id', 'spending_flag', 'spending']].head(10)
# Out:
#    user_id spending_flag  spending
# 0        1   Low Spender  6.367797
# 1        1   Low Spender  6.367797
# 2        1   Low Spender  6.367797
# 3        1   Low Spender  6.367797
# 4        1   Low Spender  6.367797
# 5        1   Low Spender  6.367797
# 6        1   Low Spender  6.367797
# 7        1   Low Spender  6.367797
# 8        1   Low Spender  6.367797
# 9        1   Low Spender  6.367797

# %%
#Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median 
#in the “days_since_prior_order” column. 

#If the median of “days_since_prior_order” is higher than 20, customer should be labeled a “Non-frequent customer.”
#If the median is higher than 10 and lower than or equal to 20, customer should be labeled a “Regular customer.”
#If the median is lower than or equal to 10, customer should be labeled a “Frequent customer.”

ords_prods_merge['frequency'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
ords_prods_merge.loc[ords_prods_merge['frequency'] > 20, 'frequency_flag'] = 'Non-frequent customer'

ords_prods_merge.loc[(ords_prods_merge['frequency'] <= 20) & (ords_prods_merge['frequency'] > 10), 'frequency_flag'] = 'Regular customer'

ords_prods_merge.loc[ords_prods_merge['frequency'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
ords_prods_merge[['user_id', 'frequency', 'frequency_flag']].head(10)
# Out:
#    user_id  frequency         frequency_flag
# 0        1       20.5  Non-frequent customer
# 1        1       20.5  Non-frequent customer
# 2        1       20.5  Non-frequent customer
# 3        1       20.5  Non-frequent customer
# 4        1       20.5  Non-frequent customer
# 5        1       20.5  Non-frequent customer
# 6        1       20.5  Non-frequent customer
# 7        1       20.5  Non-frequent customer
# 8        1       20.5  Non-frequent customer
# 9        1       20.5  Non-frequent customer

# %%
# export data frame as pickle
ords_prods_merge.to_pickle(os.path.join(path, '02_Data','Prepared Data', '4.8_ords_prods_merge.pkl'))
